# %%
import urllib.parse
raw_password = 'm@$t3rm!Nd'
encoded_password = urllib.parse.quote_plus(raw_password)
# %reload_ext sql
# %sql postgresql://root:{encoded_password}@10.0.0.2:5432/ola
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %sql SELECT * FROM rides LIMIT 5
# Out:
#  * postgresql://root:***@10.0.0.2:5432/ola
# 5 rows affected.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 get_ipython().run_line_magic('sql', 'SELECT * FROM rides LIMIT 5')
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
